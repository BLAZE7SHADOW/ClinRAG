# %%
import os
os.getcwd()
# Out:
# '/Users/shivamgovindrao/AI Folders/Clinrag/notebook'

# %%
  from docling.document_converter import DocumentConverter
  result = DocumentConverter().convert("../data/raw/metformin.pdf")
  print(result.document.export_to_markdown())
# Out:
# [INFO] 2026-07-20 14:42:54,369 [RapidOCR] base.py:23: Using engine_name: torch
# [INFO] 2026-07-20 14:42:54,370 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-07-20 14:42:54,382 [RapidOCR] download_file.py:60: File exists and is valid: /Users/shivamgovindrao/AI Folders/Clinrag/.venv/lib/python3.11/site-packages/rapidocr/models/ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-07-20 14:42:54,382 [RapidOCR] main.py:50: Using /Users/shivamgovindrao/AI Folders/Clinrag/.venv/lib/python3.11/site-packages/rapidocr/models/ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-07-20 14:42:54,523 [RapidOCR] base.py:23: Using engine_name: torch
# [INFO] 2026-07-20 14:42:54,523 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-07-20 14:42:54,526 [RapidOCR] download_file.py:60: File exists and is valid: /Users/shivamgovindrao/AI Folders/Clinrag/.venv/lib/python3.11/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_mobile.pth
# ...

# %%
from docling.document_converter import DocumentConverter,PdfFormatOption
from docling.datamodel.base_models import   InputFormat
from docling.datamodel.pipeline_options import PdfPipelineOptions,  TableFormerMode

# %%
pipeline__options = PdfPipelineOptions()
pipeline__options.table_structure_options.mode = TableFormerMode.ACCURATE

# %%
converter = DocumentConverter(format_options={InputFormat.PDF: PdfFormatOption(pipeline__options=pipeline__options)})

# %%
result = converter.convert("../data/raw/metformin.pdf")
print(result.document.export_to_markdown())
# Out:
# [INFO] 2026-07-20 12:31:36,358 [RapidOCR] base.py:23: Using engine_name: torch
# [INFO] 2026-07-20 12:31:36,359 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-07-20 12:31:36,375 [RapidOCR] download_file.py:60: File exists and is valid: /Users/shivamgovindrao/AI Folders/Clinrag/.venv/lib/python3.11/site-packages/rapidocr/models/ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-07-20 12:31:36,375 [RapidOCR] main.py:50: Using /Users/shivamgovindrao/AI Folders/Clinrag/.venv/lib/python3.11/site-packages/rapidocr/models/ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-07-20 12:31:36,540 [RapidOCR] base.py:23: Using engine_name: torch
# [INFO] 2026-07-20 12:31:36,541 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-07-20 12:31:36,542 [RapidOCR] download_file.py:60: File exists and is valid: /Users/shivamgovindrao/AI Folders/Clinrag/.venv/lib/python3.11/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_mobile.pth
# ...
